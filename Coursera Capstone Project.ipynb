# %% [markdown]
# # COURSERA CAPSTONE PROJECT - NUTTAPONGW

# %% [markdown]
# This Notebook will be mainly used in the Capstone Project in IBM Data Science Professional course

# %%
import pandas as pd
import numpy as np

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
